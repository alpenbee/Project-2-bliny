# %%
import pandas as pd
df = pd.read_csv('/Users/albik/Downloads/archive/Datafiniti_Fast_Food_Restaurants_May19.csv')
df=df.drop(['dateAdded', 'primaryCategories','country','keys','sourceURLs','websites'],axis=1)
df.isnull().sum()
df[df.duplicated()]

df = df.query('province == ["FL","OH","NE"]')
df = df.query('city == ["Columbus","Cincinnati","Cleveland", "Las Vegas", "Miami"]')

df = df.reset_index(drop=True)

display(df)
# Out:
#                        id           dateUpdated  \
# 0    AVzBCTFUFcQ3k02bBc0N  2019-05-18T01:29:17Z
# 1    AV1TprLm3D1zeR_xEzco  2019-05-18T01:29:16Z
# 2    AVweQRZQByjofQCxwnRk  2019-05-17T23:58:36Z
# 3    AV0Y365Z-gnIPe8DVVOh  2019-05-17T21:56:45Z
# 4    AVz-DxMC-gnIPe8DUqTn  2019-05-17T19:37:50Z
# ..                    ...                   ...
# 243  AVwc-hVZIN2L1WUfq7bY  2018-12-08T16:09:14Z
# 244  AVwdfn1YkufWRAb56cbc  2018-12-08T16:09:14Z
# 245  AV0Y4AqaFcQ3k02bEN5_  2018-12-08T14:07:41Z
# 246  AVwdpS8wkufWRAb577IG  2018-12-07T19:45:09Z
# 247  AWE8fwMMIxWefVJwyZRg  2018-12-03T14:49:50Z
#
#                             address  \
# 0          13575 West Dixie Highway
# 1                   8050 Nw 36th St
# 2                      4971 Vine St
# 3                2507 W Clifton Ave
# 4    4397 Glen Este Withamsville Rd
# ..                              ...
# 243                  1059 S High St
# 244                  5137 E Main St
# 245              875 W Galbraith Rd
# ...

# %%
''
